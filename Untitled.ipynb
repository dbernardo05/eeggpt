# %% [markdown]
# ###### # Provided sinusoid array
# sinusoid = np.array([0.0, 0.309, 0.5878, 0.809, 0.9511, 1.0, 0.9511, 0.809, 0.5878, 0.309, 0.0, -0.309, -0.5878, -0.809, -0.9511, -1.0, -0.9511, -0.809, -0.5878, -0.309])
#
# # Create an array of x values from 0 to 2π with the same number of points as the sinusoid array
# x_values = np.linspace(0, 2 * np.pi, len(sinusoid))
#
# # Plot the sinusoid
# plt.plot(x_values, sinusoid)
# plt.xlabel('x')
# plt.ylabel('sin(x)')
# plt.title('Sinusoid')
# plt.grid(True)
# plt.show()

# %%
# Hallucinated epileptiform spike array
spike = np.array([0.0, 0.2, 0.7, 1.5, 3.0, 5.5, 4.0, 2.2, 1.3, 0.8, 0.5, 0.3, 0.2, 0.1, 0.0, -0.1, -0.15, -0.1, -0.05, 0.0])

# Create an array of x values with the same number of points as the spike array
x_values = np.linspace(0, len(spike) - 1, len(spike))

# Plot the epileptiform spike
plt.plot(x_values, spike)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Epileptiform Spike')
plt.grid(True)
plt.show()

# %%
# Hallucinated EEG traces
t3_trace = np.array([0.0, 0.1, 0.5, 1.2, 2.5, 4.5, 5.5, 4.0, 2.5, 1.0, -1.5, -3.0, -2.5, -1.5, -0.5, 0.0, 0.2, 0.1, 0.05, 0.0])
f7_trace = np.array([0.0, 0.0, 0.1, 0.4, 1.2, 2.0, 1.5, 0.8, 0.2, -0.2, -0.5, -0.7, -0.5, -0.3, -0.1, 0.0, 0.05, 0.02, 0.01, 0.0])

# Create an array of x values with the same number of points as the traces
x_values = np.linspace(0, len(t3_trace) - 1, len(t3_trace))

# Plot the T3 trace
plt.plot(x_values, t3_trace, label='T3')

# Plot the F7 trace
plt.plot(x_values, f7_trace, label='F7')

# Customize the plot
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Left Temporal Triphasic Spike with After-going Slow-Wave')
plt.legend()
plt.grid(True)
plt.show()
